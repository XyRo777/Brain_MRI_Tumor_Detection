# %% [markdown]
# ## Importing Required Packages

# %%
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader, ConcatDataset
import glob 
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns
import random
import cv2
import sys

# %% [markdown]
# ## Reading the Data/Images

# %%
tumor = []
path = './data/brain_tumor_dataset/yes/*.jpg'
for f in glob.iglob(path):
    img = cv2.imread(f)
    img = cv2.resize(img, (128, 128))
    b, g, r = cv2.split(img)
    img = cv2.merge([r, g ,b])
    tumor.append(img)

healthy = []
path = './data/brain_tumor_dataset/no/*.jpg'
for f in glob.iglob(path):
    img = cv2.imread(f)
    img = cv2.resize(img, (128, 128))
    b, g, r = cv2.split(img)
    img = cv2.merge([r, g ,b])
    healthy.append(img)

# %%
print("No tumor : " ,len(healthy))
print("Have Tumor :", len(tumor))
# Out:
# No tumor :  91
# Have Tumor : 154

# %%
healthy = np.array(healthy)
tumor = np.array(tumor)

# %%
tumor.shape
# Out:
# (154, 128, 128, 3)

# %%
healthy.shape
# Out:
# (91, 128, 128, 3)

# %%
All = np.concatenate((healthy, tumor))
All.shape
# Out:
# (245, 128, 128, 3)

# %%
np.random.choice(10, 5, replace = False) # Replace makes sure the numbers are not repeated (test)
# Out:
# array([0, 9, 1, 5, 4])

# %% [markdown]
# ## Visualizing the MRI Images

# %%
def plot_random(healthy, tumor, num=5):
    healthy_imgs = healthy[np.random.choice(healthy.shape[0], num, replace=False)]
    tumor_imgs = tumor[np.random.choice(tumor.shape[0], num, replace=False)]
    
    plt.figure(figsize=(16,9))
    for i in range(num):
        plt.subplot(1, num, i+1)
        plt.title('healthy')
        plt.imshow(healthy_imgs[i])
        
    plt.figure(figsize=(16,9))
    for i in range(num):
        plt.subplot(1, num, i+1)
        plt.title('tumor')
        plt.imshow(tumor_imgs[i])

# %%
plot_random(healthy, tumor, num=5)

# %% [markdown]
# ## Creating Torch Dataset Class

# %%
class Dataset(object):

    def __getitem__(self, index):
        raise NotImplementedError

    def __len__(self):
        raise NotImplementedError

    def __add__(self, other):
        return ConcatDataset([self, other])

# %% [markdown]
# ## Creating MRI Custom Dataset

# %%
class MRI(Dataset):
    def __init__(self):
        
        tumor = []
        healthy = []
        
        for f in glob.iglob("./data/brain_tumor_dataset/yes/*.jpg"):
            img = cv2.imread(f)
            img = cv2.resize(img,(128,128)) 
            b, g, r = cv2.split(img)
            img = cv2.merge([r,g,b])
            img = img.reshape((img.shape[2],img.shape[0],img.shape[1]))
            tumor.append(img)

        for f in glob.iglob("./data/brain_tumor_dataset/no/*.jpg"):
            img = cv2.imread(f)
            img = cv2.resize(img,(128,128)) 
            b, g, r = cv2.split(img)
            img = cv2.merge([r,g,b])
            img = img.reshape((img.shape[2],img.shape[0],img.shape[1]))
            healthy.append(img)

        # images
        tumor = np.array(tumor,dtype=np.float32)
        healthy = np.array(healthy,dtype=np.float32)
        
        # labels
        tumor_label = np.ones(tumor.shape[0], dtype=np.float32)
        healthy_label = np.zeros(healthy.shape[0], dtype=np.float32)
        
        # concatenates
        self.images = np.concatenate((tumor, healthy), axis=0)
        self.labels = np.concatenate((tumor_label, healthy_label))
        
    def __len__(self):
        return self.images.shape[0]
    
    def __getitem__(self, index):
        
        sample = {'image': self.images[index], 'label':self.labels[index]}
        
        return sample
    
    def normalize(self):
        self.images = self.images/255.0

# %%
mri_dataset = MRI()
mri_dataset.normalize()

# %% [markdown]
# ## Dataloader

# %%
names={0:'Heathy', 1:'Tumor'}
dataloader = DataLoader(mri_dataset, shuffle=True)
for i, sample in enumerate(dataloader):
    img = sample['image'].squeeze()
    img = img.reshape((img.shape[1], img.shape[2], img.shape[0]))
    plt.title(names[sample['label'].item()])
    plt.imshow(img)
    plt.show()
    if i == 5:
        break

# %% [markdown]
# ## Evaluating the Newborn - NN (Pre-Training)

# %%
import torch.nn as nn
import torch.nn.functional as F

class CNN(nn.Module):
    def __init__(self):
        super(CNN,self).__init__()
        self.cnn_model = nn.Sequential(
        nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5),
        nn.Tanh(),
        nn.AvgPool2d(kernel_size=2, stride=5),
        nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5),
        nn.Tanh(),
        nn.AvgPool2d(kernel_size=2, stride=5))
        
        self.fc_model = nn.Sequential(
        nn.Linear(in_features=256, out_features=120),
        nn.Tanh(),
        nn.Linear(in_features=120, out_features=84),
        nn.Tanh(),
        nn.Linear(in_features=84, out_features=1))
        
    def forward(self, x):
        x = self.cnn_model(x)
        x = x.view(x.size(0), -1)
        x = self.fc_model(x)
        x = F.sigmoid(x)
        
        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


cpu_tensor = torch.rand(10).to(device)

gpu_tensor = cpu_tensor.to(device)

print(cpu_tensor, cpu_tensor.dtype, type(cpu_tensor), cpu_tensor.type())
print(gpu_tensor, gpu_tensor.dtype, type(gpu_tensor), gpu_tensor.type())

print(cpu_tensor*gpu_tensor)
# Out:
# tensor([0.9029, 0.2549, 0.6183, 0.6454, 0.7467, 0.3951, 0.8155, 0.0386, 0.6608,
#         0.8503]) torch.float32 <class 'torch.Tensor'> torch.FloatTensor
# tensor([0.9029, 0.2549, 0.6183, 0.6454, 0.7467, 0.3951, 0.8155, 0.0386, 0.6608,
#         0.8503]) torch.float32 <class 'torch.Tensor'> torch.FloatTensor
# tensor([0.8151, 0.0650, 0.3823, 0.4166, 0.5576, 0.1561, 0.6650, 0.0015, 0.4366,
#         0.7230])

# %%
mri_dataset = MRI()
mri_dataset.normalize()  
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = CNN().to(device)

# %%
dataloader = DataLoader(mri_dataset, batch_size=32, shuffle=False)

# %%
model.eval()
outputs = []
y_true = []
with torch.no_grad():
    for D in dataloader:
        image = D['image'].to(device)
        label = D['label'].to(device)

        y_hat = model(image)

        outputs.append(y_hat.cpu().detach().numpy())
        y_true.append(label.cpu().detach().numpy())
# Out:
# C:\Users\ROG\.conda\envs\MRI\lib\site-packages\torch\nn\functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")

# %%
outputs = np.concatenate( outputs, axis=0 ).squeeze()
y_true = np.concatenate( y_true, axis=0 ).squeeze()

# %%
def threshold(scores,threshold=0.50, minimum=0, maximum = 1.0):
    x = np.array(list(scores))
    x[x >= threshold] = maximum
    x[x < threshold] = minimum
    return x

# %%
accuracy_score(y_true, threshold(outputs))
# Out:
# 0.49387755102040815

# %%
plt.figure(figsize=(16,9))
cm = confusion_matrix(y_true, threshold(outputs))
ax= plt.subplot()
sns.heatmap(cm, annot=True, fmt='g', ax=ax, annot_kws={"size": 20})

ax.set_xlabel('Predicted labels', fontsize=20)
ax.set_ylabel('True labels', fontsize=20) 
ax.set_title('Confusion Matrix', fontsize=20)
ax.xaxis.set_ticklabels(['Healthy','Tumor'], fontsize=20)
ax.yaxis.set_ticklabels(['Tumor','Healthy'], fontsize=20)
# Out:
# [Text(0, 0.5, 'Tumor'), Text(0, 1.5, 'Healthy')]

# %%
plt.figure(figsize=(16,9))
plt.plot(outputs)
plt.axvline(x=len(tumor), color='r', linestyle='--')
plt.grid()

# %% [markdown]
# ## Training the model

# %%
eta = 0.0001
EPOCH = 400
optimizer = torch.optim.Adam(model.parameters(), lr=eta)
dataloader = DataLoader(mri_dataset, batch_size=32, shuffle=True)
model.train()
# Out:
# CNN(
#   (cnn_model): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#     (1): Tanh()
#     (2): AvgPool2d(kernel_size=2, stride=5, padding=0)
#     (3): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#     (4): Tanh()
#     (5): AvgPool2d(kernel_size=2, stride=5, padding=0)
#   )
#   (fc_model): Sequential(
#     (0): Linear(in_features=256, out_features=120, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=120, out_features=84, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=84, out_features=1, bias=True)
#   )
# )

# %%
for epoch in range(1, EPOCH):
    losses = []
    for D in dataloader:
        optimizer.zero_grad()
        data = D['image'].to(device)
        label = D['label'].to(device)
        y_hat = model(data)
        
        error = nn.BCELoss() 
        loss = torch.sum(error(y_hat.squeeze(), label))
        loss.backward()
        optimizer.step()
        losses.append(loss.item())
    if (epoch+1) % 10 == 0:
        print('Train Epoch: {}\tLoss: {:.6f}'.format(epoch+1, np.mean(losses)))
# Out:
# Train Epoch: 10	Loss: 0.017944
# Train Epoch: 20	Loss: 0.014002
# Train Epoch: 30	Loss: 0.011366
# Train Epoch: 40	Loss: 0.009472
# Train Epoch: 50	Loss: 0.008043
# Train Epoch: 60	Loss: 0.006927
# Train Epoch: 70	Loss: 0.006034
# Train Epoch: 80	Loss: 0.005304
# Train Epoch: 90	Loss: 0.004698
# Train Epoch: 100	Loss: 0.004188
# Train Epoch: 110	Loss: 0.003755
# Train Epoch: 120	Loss: 0.003383
# Train Epoch: 130	Loss: 0.003060
# Train Epoch: 140	Loss: 0.002779
# Train Epoch: 150	Loss: 0.002533
# Train Epoch: 160	Loss: 0.002315
# Train Epoch: 170	Loss: 0.002122
# Train Epoch: 180	Loss: 0.001949
# Train Epoch: 190	Loss: 0.001795
# Train Epoch: 200	Loss: 0.001657
# Train Epoch: 210	Loss: 0.001532
# Train Epoch: 220	Loss: 0.001419
# Train Epoch: 230	Loss: 0.001317
# Train Epoch: 240	Loss: 0.001224
# Train Epoch: 250	Loss: 0.001139
# Train Epoch: 260	Loss: 0.001061
# Train Epoch: 270	Loss: 0.000990
# Train Epoch: 280	Loss: 0.000925
# Train Epoch: 290	Loss: 0.000865
# Train Epoch: 300	Loss: 0.000809
# Train Epoch: 310	Loss: 0.000758
# Train Epoch: 320	Loss: 0.000711
# Train Epoch: 330	Loss: 0.000667
# Train Epoch: 340	Loss: 0.000627
# Train Epoch: 350	Loss: 0.000589
# Train Epoch: 360	Loss: 0.000554
# Train Epoch: 370	Loss: 0.000522
# Train Epoch: 380	Loss: 0.000492
# Train Epoch: 390	Loss: 0.000463
# Train Epoch: 400	Loss: 0.000437

# %% [markdown]
# ## Results Post-Training Procedure

# %%
model.eval()
dataloader = DataLoader(mri_dataset, batch_size=32, shuffle=False)
outputs=[]
y_true = []
with torch.no_grad():
    for D in dataloader:
        image =  D['image'].to(device)
        label = D['label'].to(device)
        
        y_hat = model(image)
        
        outputs.append(y_hat.cpu().detach().numpy())
        y_true.append(label.cpu().detach().numpy())
        
outputs = np.concatenate( outputs, axis=0 )
y_true = np.concatenate( y_true, axis=0 )

# %%
accuracy_score(y_true, threshold(outputs))
# Out:
# 1.0

# %%
cm = confusion_matrix(y_true, threshold(outputs))
plt.figure(figsize=(16,9))

ax= plt.subplot()
sns.heatmap(cm, annot=True, fmt='g', ax=ax);  

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['Tumor','Healthy'])
ax.yaxis.set_ticklabels(['Tumor','Healthy'])
# Out:
# [Text(0, 0.5, 'Tumor'), Text(0, 1.5, 'Healthy')]

# %%
plt.figure(figsize=(16,9))
plt.plot(outputs)
plt.axvline(x=len(tumor), color='r', linestyle='--')
plt.grid()

# %% [markdown]
# ## Visualising the feature maps of the Convolution Layers

# %%
model
# Out:
# CNN(
#   (cnn_model): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#     (1): Tanh()
#     (2): AvgPool2d(kernel_size=2, stride=5, padding=0)
#     (3): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#     (4): Tanh()
#     (5): AvgPool2d(kernel_size=2, stride=5, padding=0)
#   )
#   (fc_model): Sequential(
#     (0): Linear(in_features=256, out_features=120, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=120, out_features=84, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=84, out_features=1, bias=True)
#   )
# )

# %%
no_of_layers = 0
conv_layers = []

# %%
model_children = list(model.children())
model_children
# Out:
# [Sequential(
#    (0): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#    (1): Tanh()
#    (2): AvgPool2d(kernel_size=2, stride=5, padding=0)
#    (3): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#    (4): Tanh()
#    (5): AvgPool2d(kernel_size=2, stride=5, padding=0)
#  ), Sequential(
#    (0): Linear(in_features=256, out_features=120, bias=True)
#    (1): Tanh()
#    (2): Linear(in_features=120, out_features=84, bias=True)
#    (3): Tanh()
#    (4): Linear(in_features=84, out_features=1, bias=True)
#  )]

# %%
for child in model_children:
    if type(child) == nn.Sequential:
        for layer in child.children():
            if type(layer) == nn.Conv2d:
                no_of_layers += 1
                conv_layers.append(layer)

# %%
conv_layers
# Out:
# [Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1)),
#  Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))]

# %%
img = mri_dataset[108]['image']
plt.imshow(img.reshape(128,128,3))

# %%
img = torch.from_numpy(img).to(device)

# %%
img.shape
# Out:
# torch.Size([3, 128, 128])

# %%
img = img.unsqueeze(0)
img.shape
# Out:
# torch.Size([1, 3, 128, 128])

# %%
results = [conv_layers[0](img)]
for i in range(1, len(conv_layers)):
    results.append(conv_layers[i](results[-1]))
outputs = results

# %%
for num_layer in range(len(outputs)):
    plt.figure(figsize=(50, 10))
    layer_viz = outputs[num_layer].squeeze()
    print("Layer ",num_layer+1)
    for i, f in enumerate(layer_viz):
        plt.subplot(2, 8, i + 1)
        plt.imshow(f.detach().cpu().numpy())
        plt.axis("off")
    plt.show()
    plt.close()
# Out:
# Layer  1
# Layer  2

# %% [markdown]
# ## Preparing Validation Set

# %%
from sklearn.model_selection import train_test_split

# %%
class MRI(Dataset):
    
    def __init__(self):
        
        self.X_train, self.y_train, self.X_val, self.y_val = None, None, None, None
        

        self.mode = 'train'
        
        tumor = []
        healthy = []
        
        for f in glob.iglob("./data/brain_tumor_dataset/yes/*.jpg"):
            img = cv2.imread(f)
            img = cv2.resize(img,(128,128))
            b, g, r = cv2.split(img)
            img = cv2.merge([r,g,b])
            img = img.reshape((img.shape[2],img.shape[0],img.shape[1]))
            tumor.append(img)

        for f in glob.iglob("./data/brain_tumor_dataset/no/*.jpg"):
            img = cv2.imread(f)
            img = cv2.resize(img,(128,128)) 
            b, g, r = cv2.split(img)
            img = cv2.merge([r,g,b])
            img = img.reshape((img.shape[2],img.shape[0],img.shape[1]))
            healthy.append(img)

        # images
        tumor = np.array(tumor,dtype=np.float32)
        healthy = np.array(healthy,dtype=np.float32)
        
        # labels
        tumor_label = np.ones(tumor.shape[0], dtype=np.float32)
        healthy_label = np.zeros(healthy.shape[0], dtype=np.float32)
        
        self.images = np.concatenate((tumor, healthy), axis=0)
        self.labels = np.concatenate((tumor_label, healthy_label))
    
    
    def train_val_split(self):
        self.X_train, self.X_val, self.y_train, self.y_val = \
        train_test_split(self.images, self.labels, test_size=0.20, random_state=42)
        
    def __len__(self):
        if self.mode == 'train':
            return self.X_train.shape[0]
        elif self.mode == 'val':
            return self.X_val.shape[0]
    
    def __getitem__(self, idx):
        if self.mode== 'train':
            sample = {'image': self.X_train[idx], 'label': self.y_train[idx]}
        
        elif self.mode== 'val':
            sample = {'image': self.X_val[idx], 'label': self.y_val[idx]}
        
        return sample
    
    def normalize(self):
        self.images = self.images/255.0

# %% [markdown]
# ## Checking for Overfitting

# %%
mri_dataset = MRI()
mri_dataset.normalize()
mri_dataset.train_val_split()

# %%
train_dataloader = DataLoader(mri_dataset, batch_size=32, shuffle=True)
val_dataloader = DataLoader(mri_dataset, batch_size=32, shuffle=False)

# %%
device = torch.device("cpu")
model = CNN().to(device)

# %%
eta=0.0001
optimizer = torch.optim.Adam(model.parameters(), lr=eta)

# %%
epoch_train_loss = []
epoch_val_loss = []

# %%
for epoch in range(1,600):
    train_losses = []
    
    model.train()
    mri_dataset.mode = 'train'
    for D in train_dataloader:
        
        optimizer.zero_grad()
        data = D['image'].to(device)
        label = D['label'].to(device)
        
        y_hat = model(data)
        error = nn.BCELoss()
        loss = torch.sum(error(y_hat.squeeze(), label))
        loss.backward()
        optimizer.step()
        train_losses.append(loss.item())
    
    epoch_train_loss.append(np.mean(train_losses))
    

    val_losses = []
    model.eval()
    
    mri_dataset.mode = 'val'
    
    with torch.no_grad():
        for D in val_dataloader:            
            data = D['image'].to(device)
            label = D['label'].to(device)
            y_hat = model(data)
            error = nn.BCELoss()
            loss = torch.sum(error(y_hat.squeeze(), label))
            val_losses.append(loss.item())
    
    epoch_val_loss.append(np.mean(val_losses))
    
    if (epoch+1) % 10 == 0:
        print('Train Epoch: {}\tTrain Loss: {:.6f}\tVal Loss: {:.6f}'.format(epoch+1, np.mean(train_losses),np.mean(val_losses)))
# Out:
# Train Epoch: 10	Train Loss: 0.622301	Val Loss: 0.588267
# Train Epoch: 20	Train Loss: 0.607414	Val Loss: 0.585219
# Train Epoch: 30	Train Loss: 0.573563	Val Loss: 0.564152
# Train Epoch: 40	Train Loss: 0.545526	Val Loss: 0.551937
# Train Epoch: 50	Train Loss: 0.505465	Val Loss: 0.567302
# Train Epoch: 60	Train Loss: 0.485412	Val Loss: 0.585012
# Train Epoch: 70	Train Loss: 0.474173	Val Loss: 0.601278
# Train Epoch: 80	Train Loss: 0.459519	Val Loss: 0.608140
# Train Epoch: 90	Train Loss: 0.423168	Val Loss: 0.614107
# Train Epoch: 100	Train Loss: 0.434795	Val Loss: 0.613427
# Train Epoch: 110	Train Loss: 0.395575	Val Loss: 0.637489
# Train Epoch: 120	Train Loss: 0.366108	Val Loss: 0.645091
# Train Epoch: 130	Train Loss: 0.370526	Val Loss: 0.637183
# Train Epoch: 140	Train Loss: 0.348789	Val Loss: 0.651140
# Train Epoch: 150	Train Loss: 0.358757	Val Loss: 0.660061
# Train Epoch: 160	Train Loss: 0.320987	Val Loss: 0.655492
# Train Epoch: 170	Train Loss: 0.318856	Val Loss: 0.662246
# Train Epoch: 180	Train Loss: 0.364888	Val Loss: 0.638018
# Train Epoch: 190	Train Loss: 0.292118	Val Loss: 0.643911
# Train Epoch: 200	Train Loss: 0.280888	Val Loss: 0.636105
# Train Epoch: 210	Train Loss: 0.303437	Val Loss: 0.634966
# Train Epoch: 220	Train Loss: 0.251779	Val Loss: 0.632843
# Train Epoch: 230	Train Loss: 0.286536	Val Loss: 0.649537
# Train Epoch: 240	Train Loss: 0.225818	Val Loss: 0.644343
# Train Epoch: 250	Train Loss: 0.214452	Val Loss: 0.645182
# Train Epoch: 260	Train Loss: 0.196685	Val Loss: 0.665846
# Train Epoch: 270	Train Loss: 0.210643	Val Loss: 0.690497
# Train Epoch: 280	Train Loss: 0.186587	Val Loss: 0.713886
# Train Epoch: 290	Train Loss: 0.148676	Val Loss: 0.716567
# Train Epoch: 300	Train Loss: 0.134027	Val Loss: 0.775019
# Train Epoch: 310	Train Loss: 0.148970	Val Loss: 0.795545
# Train Epoch: 320	Train Loss: 0.124204	Val Loss: 0.826839
# Train Epoch: 330	Train Loss: 0.086843	Val Loss: 0.872035
# Train Epoch: 340	Train Loss: 0.090542	Val Loss: 0.898967
# Train Epoch: 350	Train Loss: 0.069714	Val Loss: 0.949451
# Train Epoch: 360	Train Loss: 0.070227	Val Loss: 0.992834
# Train Epoch: 370	Train Loss: 0.053133	Val Loss: 1.026814
# Train Epoch: 380	Train Loss: 0.044550	Val Loss: 1.093282
# Train Epoch: 390	Train Loss: 0.062154	Val Loss: 1.110548
# Train Epoch: 400	Train Loss: 0.039259	Val Loss: 1.163128
# Train Epoch: 410	Train Loss: 0.033987	Val Loss: 1.204830
# Train Epoch: 420	Train Loss: 0.023351	Val Loss: 1.245311
# Train Epoch: 430	Train Loss: 0.026678	Val Loss: 1.303041
# Train Epoch: 440	Train Loss: 0.018638	Val Loss: 1.333081
# Train Epoch: 450	Train Loss: 0.019094	Val Loss: 1.368068
# Train Epoch: 460	Train Loss: 0.013837	Val Loss: 1.396378
# Train Epoch: 470	Train Loss: 0.012896	Val Loss: 1.436416
# Train Epoch: 480	Train Loss: 0.010301	Val Loss: 1.455682
# Train Epoch: 490	Train Loss: 0.009985	Val Loss: 1.488062
# Train Epoch: 500	Train Loss: 0.009509	Val Loss: 1.515798
# Train Epoch: 510	Train Loss: 0.008708	Val Loss: 1.542461
# Train Epoch: 520	Train Loss: 0.007343	Val Loss: 1.576221
# Train Epoch: 530	Train Loss: 0.008205	Val Loss: 1.598920
# Train Epoch: 540	Train Loss: 0.005008	Val Loss: 1.625462
# Train Epoch: 550	Train Loss: 0.005304	Val Loss: 1.644860
# Train Epoch: 560	Train Loss: 0.004784	Val Loss: 1.665239
# Train Epoch: 570	Train Loss: 0.004154	Val Loss: 1.690642
# Train Epoch: 580	Train Loss: 0.003548	Val Loss: 1.710917
# Train Epoch: 590	Train Loss: 0.004173	Val Loss: 1.724304
# Train Epoch: 600	Train Loss: 0.003305	Val Loss: 1.752978

# %%
plt.figure(figsize=(16,9))
plt.plot(epoch_train_loss, c='b', label='Train loss')
plt.plot(epoch_val_loss, c='r', label = 'Validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epochs', fontsize=20)
plt.ylabel('Loss', fontsize=20)
# Out:
# Text(0, 0.5, 'Loss')
